# %%
import pandas as pd

# %%
df = pd.read_csv("AnnualTicketSales.csv")

# %%
df
# Out:
#     YEAR    TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021    42,37,74,881   $3,881,777,912                      $3,881,777,912
# 1   2020    22,36,38,958   $2,048,534,616                      $2,048,534,616
# 2   2019  1,22,85,41,629  $11,253,443,955                     $11,253,444,050
# 3   2018  1,31,15,36,128  $11,948,096,650                     $12,013,670,952
# 4   2017  1,22,56,39,761  $10,993,991,460                     $11,226,860,216
# 5   2016  1,30,25,56,378  $11,267,115,924                     $11,931,416,424
# 6   2015  1,32,33,56,776  $11,155,900,636                     $12,121,948,075
# 7   2014  1,25,74,02,920  $10,272,985,008                     $11,517,810,744
# 8   2013  1,33,91,68,926  $10,887,446,341                     $12,266,787,382
# 9   2012  1,38,09,21,942  $10,992,141,616                     $12,649,244,986
# 10  2011  1,28,29,15,168  $10,173,519,704                     $11,751,502,955
# ...

# %%
df.tail()
# Out:
#     YEAR    TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 22  1999  1,44,46,64,086   $7,338,894,852                     $13,233,123,027
# 23  1998  1,44,38,32,471   $6,771,575,283                     $13,225,505,439
# 24  1997  1,35,73,49,648   $6,230,235,770                     $12,433,322,785
# 25  1996  1,30,52,21,290   $5,769,078,886                     $11,955,781,912
# 26  1995  1,22,17,05,907   $5,314,421,390                     $11,190,826,105
#
#    AVERAGE TICKET PRICE  Unnamed: 5
# 22                $5.08         NaN
# 23                $4.69         NaN
# 24                $4.59         NaN
# 25                $4.42         NaN
# 26                $4.35         NaN

# %%
df.drop("Unnamed: 5", axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# YEAR                                   0
# TICKETS SOLD                           0
# TOTAL BOX OFFICE                       0
# TOTAL INFLATION ADJUSTED BOX OFFICE    0
# AVERAGE TICKET PRICE                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["TICKETS SOLD"].dtype
# Out:
# dtype('O')

# %%
df["TICKETS SOLD"] = df["TICKETS SOLD"].str.replace(",", "")

# %%
df["TICKETS SOLD"] = df["TICKETS SOLD"].apply(lambda x: float(x))

# %%
df["TICKETS SOLD"].dtype
# Out:
# dtype('float64')

# %%
df["TOTAL BOX OFFICE"] = df["TOTAL BOX OFFICE"].str.replace("," , "")

# %%
df
# Out:
#     YEAR  TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021  4.237749e+08      $3881777912                      $3,881,777,912
# 1   2020  2.236390e+08      $2048534616                      $2,048,534,616
# 2   2019  1.228542e+09     $11253443955                     $11,253,444,050
# 3   2018  1.311536e+09     $11948096650                     $12,013,670,952
# 4   2017  1.225640e+09     $10993991460                     $11,226,860,216
# 5   2016  1.302556e+09     $11267115924                     $11,931,416,424
# 6   2015  1.323357e+09     $11155900636                     $12,121,948,075
# 7   2014  1.257403e+09     $10272985008                     $11,517,810,744
# 8   2013  1.339169e+09     $10887446341                     $12,266,787,382
# 9   2012  1.380922e+09     $10992141616                     $12,649,244,986
# 10  2011  1.282915e+09     $10173519704                     $11,751,502,955
# ...

# %%
df["TOTAL BOX OFFICE"] = df["TOTAL BOX OFFICE"].apply(lambda x: float(x[1:]))

# %%
df["TOTAL BOX OFFICE"].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#     YEAR  TICKETS SOLD  TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021  4.237749e+08      3.881778e+09                      $3,881,777,912
# 1   2020  2.236390e+08      2.048535e+09                      $2,048,534,616
# 2   2019  1.228542e+09      1.125344e+10                     $11,253,444,050
# 3   2018  1.311536e+09      1.194810e+10                     $12,013,670,952
# 4   2017  1.225640e+09      1.099399e+10                     $11,226,860,216
# 5   2016  1.302556e+09      1.126712e+10                     $11,931,416,424
# 6   2015  1.323357e+09      1.115590e+10                     $12,121,948,075
# 7   2014  1.257403e+09      1.027299e+10                     $11,517,810,744
# 8   2013  1.339169e+09      1.088745e+10                     $12,266,787,382
# 9   2012  1.380922e+09      1.099214e+10                     $12,649,244,986
# 10  2011  1.282915e+09      1.017352e+10                     $11,751,502,955
# ...

# %%
sub = 0
for i in df["TOTAL BOX OFFICE"]:
    sub = sub + i
    print(sub)
# Out:
# 3881777912.0
# 5930312528.0
# 17183756483.0
# 29131853133.0
# 40125844593.0
# 51392960517.0
# 62548861153.0
# 72821846161.0
# 83709292502.0
# 94701434118.0
# 104874953822.0
# 115357207847.0
# 125996465131.0
# 135747209279.0
# 145517064193.0
# 154678802414.0
# 163479608132.0
# 172767604651.0
# 181960881940.0
# 191116029155.0
# 199412878791.0
# 206945190270.0
# 214284085122.0
# 221055660405.0
# 227285896175.0
# 233054975061.0
# 238369396451.0

# %%
df["TOTAL INFLATION ADJUSTED BOX OFFICE"] = df["TOTAL INFLATION ADJUSTED BOX OFFICE"].str.replace("," , "")

# %%
df["TOTAL INFLATION ADJUSTED BOX OFFICE"] = df["TOTAL INFLATION ADJUSTED BOX OFFICE"].apply(lambda x: float(x[1:]))

# %%
df["TOTAL INFLATION ADJUSTED BOX OFFICE"].dtype
# Out:
# dtype('float64')

# %%
df["AVERAGE TICKET PRICE"] = df["AVERAGE TICKET PRICE"].str.replace(",", "")

# %%
df["AVERAGE TICKET PRICE"] = df["AVERAGE TICKET PRICE"].apply(lambda x: float(x[1:]))

# %%
df["AVERAGE TICKET PRICE"].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#     YEAR  TICKETS SOLD  TOTAL BOX OFFICE  TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021  4.237749e+08      3.881778e+09                         3.881778e+09
# 1   2020  2.236390e+08      2.048535e+09                         2.048535e+09
# 2   2019  1.228542e+09      1.125344e+10                         1.125344e+10
# 3   2018  1.311536e+09      1.194810e+10                         1.201367e+10
# 4   2017  1.225640e+09      1.099399e+10                         1.122686e+10
# 5   2016  1.302556e+09      1.126712e+10                         1.193142e+10
# 6   2015  1.323357e+09      1.115590e+10                         1.212195e+10
# 7   2014  1.257403e+09      1.027299e+10                         1.151781e+10
# 8   2013  1.339169e+09      1.088745e+10                         1.226679e+10
# 9   2012  1.380922e+09      1.099214e+10                         1.264924e+10
# 10  2011  1.282915e+09      1.017352e+10                         1.175150e+10
# ...

# %%
df["YEAR"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Highest Grossers.csv

# %%
hg = pd.read_csv("HighestGrossers.csv")

# %%
hg
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# ...

# %%
hg.duplicated().sum()
# Out:
# 0

# %%
hg.isnull().sum()
# Out:
# YEAR                     0
# MOVIE                    0
# GENRE                    3
# MPAA RATING              0
# DISTRIBUTOR              0
# TOTAL FOR YEAR           0
# TOTAL IN 2019 DOLLARS    0
# TICKETS SOLD             0
# dtype: int64

# %%
hg["GENRE"].fillna("Drama", inplace = True)

# %%
hg
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# ...

# %%
hg["GENRE"].unique()
# Out:
# array(['Drama', 'Adventure', 'Action'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l_enco = LabelEncoder()

# %%
hg["GENRE"] = l_enco.fit_transform(hg["GENRE"])

# %%
hg
# Out:
#     YEAR                                          MOVIE  GENRE MPAA RATING  \
# 0   1995                                 Batman Forever      2       PG-13
# 1   1996                               Independence Day      1       PG-13
# 2   1997                                   Men in Black      1       PG-13
# 3   1998                                        Titanic      1       PG-13
# 4   1999            Star Wars Ep. I: The Phantom Menace      1          PG
# 5   2000                 How the Grinch Stole Christmas      1          PG
# 6   2001          Harry Potter and the Sorcerer’s Stone      1          PG
# 7   2002                                     Spider-Man      1       PG-13
# 8   2003                                   Finding Nemo      1           G
# 9   2004                                        Shrek 2      1          PG
# 10  2005         Star Wars Ep. III: Revenge of the Sith      0       PG-13
# ...

# %%
hg["MPAA RATING"].unique()
# Out:
# array(['PG-13', 'PG', 'G', 'R'], dtype=object)

# %%
hg["MPAA RATING"] = l_enco.fit_transform(hg["MPAA RATING"])

# %%
len(hg["DISTRIBUTOR"].unique())
# Out:
# 7

# %%
hg["DISTRIBUTOR"] = l_enco.fit_transform(hg["DISTRIBUTOR"])

# %%
hg["TOTAL FOR YEAR"] = hg["TOTAL FOR YEAR"].str.replace("," , "")

# %%
hg["TOTAL FOR YEAR"] = hg["TOTAL FOR YEAR"].apply(lambda x: float(x[1:]))

# %%
hg["TOTAL FOR YEAR"].dtype
# Out:
# dtype('float64')

# %%
hg["TOTAL IN 2019 DOLLARS"] = hg["TOTAL IN 2019 DOLLARS"].str.replace("," , "")

# %%
hg["TOTAL IN 2019 DOLLARS"] = hg["TOTAL IN 2019 DOLLARS"].apply(lambda x: float(x[1:]))

# %%
hg["TICKETS SOLD"] = hg["TICKETS SOLD"].str.replace("," , "")

# %%
hg["TICKETS SOLD"] = hg["TICKETS SOLD"].apply(lambda x: float(x))

# %%
hg["TICKETS SOLD"].dtype
# Out:
# dtype('float64')

# %%
hg
# Out:
#     YEAR                                          MOVIE  GENRE  MPAA RATING  \
# 0   1995                                 Batman Forever      2            2
# 1   1996                               Independence Day      1            2
# 2   1997                                   Men in Black      1            2
# 3   1998                                        Titanic      1            2
# 4   1999            Star Wars Ep. I: The Phantom Menace      1            1
# 5   2000                 How the Grinch Stole Christmas      1            1
# 6   2001          Harry Potter and the Sorcerer’s Stone      1            1
# 7   2002                                     Spider-Man      1            2
# 8   2003                                   Finding Nemo      1            0
# 9   2004                                        Shrek 2      1            1
# 10  2005         Star Wars Ep. III: Revenge of the Sith      0            2
# ...

# %%
hg.drop("MOVIE" , axis = 1, inplace = True)

# %%
hg
# Out:
#     YEAR  GENRE  MPAA RATING  DISTRIBUTOR  TOTAL FOR YEAR  \
# 0   1995      2            2            6     184031112.0
# 1   1996      1            2            0     306169255.0
# 2   1997      1            2            3     250650052.0
# 3   1998      1            2            2     443319081.0
# 4   1999      1            1            0     430443350.0
# 5   2000      1            1            4     253367455.0
# 6   2001      1            1            6     300404434.0
# 7   2002      1            2            3     403706375.0
# 8   2003      1            0            5     339714367.0
# 9   2004      1            1            1     441226247.0
# 10  2005      0            2            0     380270577.0
# 11  2006      0            2            5     423315812.0
# 12  2007      1            2            3     336530303.0
# 13  2008      1            2            6     531001578.0
# 14  2009      0            2            2     402111870.0
# ...
